# %% [markdown]
# # Adam Callum Duker - CyberSecurity and Digital Forensics - ID: 33732635
# I am submitting Exam Paper 1

# %% [markdown]
# ## My programming best
#
# I find that I work the **best** when I break down my tasks of what the code is telling my first, such as the *Happy Path* and then coding the defensive and safety nets around my code, while some people my think this isn't the most effective. I like to plan out my code mentally and sometime by hand as a
# > "set of rules"
#
# A **calm and peaceful** is the best for me to focus on the task at hand.
# I like to use VS Code out of habbit, but I think it may be time to research if they other IDE's may be better for me, my pattern of problem solving is: <br>
#
# ### My chain of problem solving
# 1. map out the problem.
# 2. find the happy path.
# 3. find the working solution.
# 4. add safety and error controls in

# %%
number = int(input("Enter a number: "))

if number % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Even

# %%
numberlist = [3,4,2,4,2]

def numbercheck(numberlist):
    results = []
    while True:
            for number in numberlist:
                if number >= 0 or number <= 100:
                    result = ("True")
                    results.append(result)
                else:
                    result = ("False")
                    results.append(result)
                if len(numberlist) == len(results):
                    break
                else:
                    continue
            if ("False") in results:
                 return ("False")
            else:
                 return ("True")

answer = numbercheck(numberlist)
print(answer)
# Out:
# True

# %%
inputs = []

while True:
    user_data = input("Enter a input: ")
    if user_data == "" :
        break
    inputs.append(user_data)

print (len(inputs))
# Out:
# 2
